# %%
import pandas as pd
import numpy as np
df=pd.read_excel('CTG.xls','Data')
df.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0          b          e         AC         FM         UC         DL
# 1        240        357          0          0          0          0
# 2          5        632          4          0          4          2
# 3        177        779          2          0          5          2
# 4        411       1192          2          0          6          2
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9  ... Unnamed: 36 Unnamed: 37  \
# 0         DS         DP         DR         NaN  ...           E          AD
# 1          0          0          0         NaN  ...          -1          -1
# 2          0          0          0         NaN  ...          -1           1
# 3          0          0          0         NaN  ...          -1           1
# 4          0          0          0         NaN  ...          -1           1
#
#   Unnamed: 38 Unnamed: 39 Unnamed: 40 Unnamed: 41 Unnamed: 42     22  \
# ...

# %%
df.shape
# Out:
# (2130, 46)

# %%
df.tail()
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 2125       1576       3049          1          0          9          0
# 2126       2796       3415          1          1          5          0
# 2127        NaN        NaN        NaN        NaN        NaN        NaN
# 2128        NaN        NaN        NaN        NaN        NaN          0
# 2129        NaN        NaN        NaN        564         23         16
#
#      Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9  ... Unnamed: 36  \
# 2125          0          0          0         NaN  ...           1
# 2126          0          0          0         NaN  ...          -1
# 2127        NaN        NaN        NaN         NaN  ...         NaN
# 2128          0          0          0         NaN  ...          72
# 2129          1          4          0         NaN  ...         NaN
#
#      Unnamed: 37 Unnamed: 38 Unnamed: 39 Unnamed: 40 Unnamed: 41 Unnamed: 42  \
# ...

# %%
df.columns=df.iloc[0]
df.head()
# Out:
# 0    b     e  AC  FM  UC  DL  DS  DP  DR NaN  ...   E  AD  DE  LD  FS  SUSP  \
# 0    b     e  AC  FM  UC  DL  DS  DP  DR NaN  ...   E  AD  DE  LD  FS  SUSP
# 1  240   357   0   0   0   0   0   0   0 NaN  ...  -1  -1  -1  -1   1    -1
# 2    5   632   4   0   4   2   0   0   0 NaN  ...  -1   1  -1  -1  -1    -1
# 3  177   779   2   0   5   2   0   0   0 NaN  ...  -1   1  -1  -1  -1    -1
# 4  411  1192   2   0   6   2   0   0   0 NaN  ...  -1   1  -1  -1  -1    -1
#
# 0 NaN  CLASS NaN  NSP
# 0 NaN  CLASS NaN  NSP
# 1 NaN      9 NaN    2
# 2 NaN      6 NaN    1
# 3 NaN      6 NaN    1
# 4 NaN      6 NaN    1
#
# [5 rows x 46 columns]

# %%
df=df[1:]
df.head()
# Out:
# 0    b     e AC FM UC DL DS DP DR NaN  ...   E  AD  DE  LD  FS SUSP NaN CLASS  \
# 1  240   357  0  0  0  0  0  0  0 NaN  ...  -1  -1  -1  -1   1   -1 NaN     9
# 2    5   632  4  0  4  2  0  0  0 NaN  ...  -1   1  -1  -1  -1   -1 NaN     6
# 3  177   779  2  0  5  2  0  0  0 NaN  ...  -1   1  -1  -1  -1   -1 NaN     6
# 4  411  1192  2  0  6  2  0  0  0 NaN  ...  -1   1  -1  -1  -1   -1 NaN     6
# 5  533  1147  4  0  5  0  0  0  0 NaN  ...  -1  -1  -1  -1  -1   -1 NaN     2
#
# 0 NaN NSP
# 1 NaN   2
# 2 NaN   1
# 3 NaN   1
# 4 NaN   1
# 5 NaN   1
#
# [5 rows x 46 columns]

# %%
df=df.iloc[:2126]
df.tail()
# Out:
# 0        b     e AC FM UC DL DS DP DR NaN  ...   E  AD  DE  LD  FS SUSP NaN  \
# 2122  2059  2867  0  0  6  0  0  0  0 NaN  ...   1  -1  -1  -1  -1   -1 NaN
# 2123  1576  2867  1  0  9  0  0  0  0 NaN  ...   1  -1  -1  -1  -1   -1 NaN
# 2124  1576  2596  1  0  7  0  0  0  0 NaN  ...   1  -1  -1  -1  -1   -1 NaN
# 2125  1576  3049  1  0  9  0  0  0  0 NaN  ...   1  -1  -1  -1  -1   -1 NaN
# 2126  2796  3415  1  1  5  0  0  0  0 NaN  ...  -1  -1  -1  -1  -1   -1 NaN
#
# 0    CLASS NaN NSP
# 2122     5 NaN   2
# 2123     5 NaN   2
# 2124     5 NaN   2
# 2125     5 NaN   2
# 2126     1 NaN   1
#
# [5 rows x 46 columns]

# %%
df1=df.loc[:,'LB':'Tendency']
df1.head()
# Out:
# 0   LB        AC FM        UC        DL DS DP ASTV MSTV ALTV  ... Width Min  \
# 1  120         0  0         0         0  0  0   73  0.5   43  ...    64  62
# 2  132   0.00638  0   0.00638   0.00319  0  0   17  2.1    0  ...   130  68
# 3  133  0.003322  0  0.008306  0.003322  0  0   16  2.1    0  ...   130  68
# 4  134  0.002561  0  0.007682  0.002561  0  0   16  2.4    0  ...   117  53
# 5  132  0.006515  0  0.008143         0  0  0   16  2.4    0  ...   117  53
#
# 0  Max Nmax Nzeros Mode Mean Median Variance Tendency
# 1  126    2      0  120  137    121       73        1
# 2  198    6      1  141  136    140       12        0
# 3  198    5      1  141  135    138       13        0
# 4  170   11      0  137  134    137       13        1
# 5  170    9      0  137  136    138       11        1
#
# [5 rows x 21 columns]

# %%
df2=df.iloc[:,[-3,-1]]
df2.head()
# Out:
# 0 CLASS NSP
# 1     9   2
# 2     6   1
# 3     6   1
# 4     6   1
# 5     2   1

# %%
df=pd.concat([df1,df2],axis=1)
df.head()
# Out:
# 0   LB        AC FM        UC        DL DS DP ASTV MSTV ALTV  ...  Max Nmax  \
# 1  120         0  0         0         0  0  0   73  0.5   43  ...  126    2
# 2  132   0.00638  0   0.00638   0.00319  0  0   17  2.1    0  ...  198    6
# 3  133  0.003322  0  0.008306  0.003322  0  0   16  2.1    0  ...  198    5
# 4  134  0.002561  0  0.007682  0.002561  0  0   16  2.4    0  ...  170   11
# 5  132  0.006515  0  0.008143         0  0  0   16  2.4    0  ...  170    9
#
# 0 Nzeros Mode Mean Median Variance Tendency CLASS NSP
# 1      0  120  137    121       73        1     9   2
# 2      1  141  136    140       12        0     6   1
# 3      1  141  135    138       13        0     6   1
# 4      0  137  134    137       13        1     6   1
# 5      0  137  136    138       11        1     2   1
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (2126, 23)

# %% [markdown]
#  # df.to_csv('smdm_data.csv')

# %% [markdown]
#  # dy=pd.read_csv('smdm_data.csv')
#  # dy.head()
