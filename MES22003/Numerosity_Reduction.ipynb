# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('mean_data.csv')
df.head()
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0         252  1.213399  0.072473 -0.849126  0.377634 -0.978351 -1.304464
# 1         738  1.068438 -3.660999 -2.354720 -1.503755  0.967588 -0.132138
# 2         868  1.881475 -3.642864 -0.771777 -0.922823  0.853488  1.022973
# 3        1330  3.620823  1.115139  0.238179  0.190368  0.049322  1.401446
# 4        1562  1.475338 -1.892178 -1.107670  0.747973  0.529871  0.683457
#
#           6         7         8         9        10  CLASS  NSP
# 0 -0.222651  0.805802 -0.154134 -0.828378 -0.802710      6    1
# 1 -0.882861  0.591740  1.345747 -0.346750 -0.007154      2    1
# 2 -0.352025  0.828647 -1.065434 -1.185671 -0.175735      2    1
# 3  0.308535 -1.156985  0.285555 -0.507672  0.261899      7    2
# 4 -0.311696 -0.042222  0.032792  0.123623  0.483177      1    1

# %%
df=df.iloc[:,1:]
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.213399  0.072473 -0.849126  0.377634 -0.978351 -1.304464 -0.222651
# 1  1.068438 -3.660999 -2.354720 -1.503755  0.967588 -0.132138 -0.882861
# 2  1.881475 -3.642864 -0.771777 -0.922823  0.853488  1.022973 -0.352025
# 3  3.620823  1.115139  0.238179  0.190368  0.049322  1.401446  0.308535
# 4  1.475338 -1.892178 -1.107670  0.747973  0.529871  0.683457 -0.311696
#
#           7         8         9        10  CLASS  NSP
# 0  0.805802 -0.154134 -0.828378 -0.802710      6    1
# 1  0.591740  1.345747 -0.346750 -0.007154      2    1
# 2  0.828647 -1.065434 -1.185671 -0.175735      2    1
# 3 -1.156985  0.285555 -0.507672  0.261899      7    2
# 4 -0.042222  0.032792  0.123623  0.483177      1    1

# %%
df.iloc[:,:11].hist()
plt.show()

# %%
df.iloc[:,0:9].boxplot()
plt.show()

# %%
df['bins']=pd.qcut(df['0'],q=200,precision=6)
df['mean_values']=df[['0','bins']].groupby('bins').transform('mean')
df['0']=df['mean_values']
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.206963  0.072473 -0.849126  0.377634 -0.978351 -1.304464 -0.222651
# 1  1.070110 -3.660999 -2.354720 -1.503755  0.967588 -0.132138 -0.882861
# 2  1.896441 -3.642864 -0.771777 -0.922823  0.853488  1.022973 -0.352025
# 3  3.640134  1.115139  0.238179  0.190368  0.049322  1.401446  0.308535
# 4  1.472491 -1.892178 -1.107670  0.747973  0.529871  0.683457 -0.311696
#
#           7         8         9        10  CLASS  NSP                  bins  \
# 0  0.805802 -0.154134 -0.828378 -0.802710      6    1  (1.171891, 1.226179]
# 1  0.591740  1.345747 -0.346750 -0.007154      2    1   (1.04723, 1.089311]
# 2  0.828647 -1.065434 -1.185671 -0.175735      2    1  (1.877723, 1.924134]
# 3 -1.156985  0.285555 -0.507672  0.261899      7    2   (3.62059, 3.659609]
# 4 -0.042222  0.032792  0.123623  0.483177      1    1  (1.463594, 1.482917]
#
#    mean_values
# 0     1.206963
# 1     1.070110
# 2     1.896441
# ...

# %%
df['0']=df['mean_values']
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.206963  0.072473 -0.849126  0.377634 -0.978351 -1.304464 -0.222651
# 1  1.070110 -3.660999 -2.354720 -1.503755  0.967588 -0.132138 -0.882861
# 2  1.896441 -3.642864 -0.771777 -0.922823  0.853488  1.022973 -0.352025
# 3  3.640134  1.115139  0.238179  0.190368  0.049322  1.401446  0.308535
# 4  1.472491 -1.892178 -1.107670  0.747973  0.529871  0.683457 -0.311696
#
#           7         8         9        10  CLASS  NSP                  bins  \
# 0  0.805802 -0.154134 -0.828378 -0.802710      6    1  (1.171891, 1.226179]
# 1  0.591740  1.345747 -0.346750 -0.007154      2    1   (1.04723, 1.089311]
# 2  0.828647 -1.065434 -1.185671 -0.175735      2    1  (1.877723, 1.924134]
# 3 -1.156985  0.285555 -0.507672  0.261899      7    2   (3.62059, 3.659609]
# 4 -0.042222  0.032792  0.123623  0.483177      1    1  (1.463594, 1.482917]
#
#    mean_values
# 0     1.206963
# 1     1.070110
# 2     1.896441
# ...

# %%
df['0'].hist()
plt.show()

# %% [markdown]
# # To ιστόγραμμα παραμένει 'ίδιο' ωστόσο περιορίσαμε τις τιμές του πρώτου feature

# %%
df['bins']=pd.qcut(df['1'],q=250,precision=6)
df['mean_values']=df[['1','bins']].groupby('bins').transform('mean')
df['1']=df['mean_values']
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.206963  0.072368 -0.849126  0.377634 -0.978351 -1.304464 -0.222651
# 1  1.070110 -3.654510 -2.354720 -1.503755  0.967588 -0.132138 -0.882861
# 2  1.896441 -3.654510 -0.771777 -0.922823  0.853488  1.022973 -0.352025
# 3  3.640134  1.105328  0.238179  0.190368  0.049322  1.401446  0.308535
# 4  1.472491 -1.886492 -1.107670  0.747973  0.529871  0.683457 -0.311696
#
#           7         8         9        10  CLASS  NSP                    bins  \
# 0  0.805802 -0.154134 -0.828378 -0.802710      6    1  (0.0654596, 0.0854084]
# 1  0.591740  1.345747 -0.346750 -0.007154      2    1  (-3.747654, -3.615989]
# 2  0.828647 -1.065434 -1.185671 -0.175735      2    1  (-3.747654, -3.615989]
# 3 -1.156985  0.285555 -0.507672  0.261899      7    2    (1.094737, 1.115307]
# 4 -0.042222  0.032792  0.123623  0.483177      1    1    (-1.89902, -1.87032]
#
#    mean_values
# 0     0.072368
# 1    -3.654510
# ...

# %%
df['1'].hist()
plt.show()

# %%
df['bins']=pd.qcut(df['2'],q=300,precision=5)
df['mean_values']=df[['2','bins']].groupby('bins').transform('mean')
df['2']=df['mean_values']
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.206963  0.072368 -0.854993  0.377634 -0.978351 -1.304464 -0.222651
# 1  1.070110 -3.654510 -2.377955 -1.503755  0.967588 -0.132138 -0.882861
# 2  1.896441 -3.654510 -0.768501 -0.922823  0.853488  1.022973 -0.352025
# 3  3.640134  1.105328  0.237479  0.190368  0.049322  1.401446  0.308535
# 4  1.472491 -1.886492 -1.110267  0.747973  0.529871  0.683457 -0.311696
#
#           7         8         9        10  CLASS  NSP                  bins  \
# 0  0.805802 -0.154134 -0.828378 -0.802710      6    1  (-0.86178, -0.84864]
# 1  0.591740  1.345747 -0.346750 -0.007154      2    1  (-2.39957, -2.35341]
# 2  0.828647 -1.065434 -1.185671 -0.175735      2    1  (-0.77292, -0.76049]
# 3 -1.156985  0.285555 -0.507672  0.261899      7    2     (0.23172, 0.2422]
# 4 -0.042222  0.032792  0.123623  0.483177      1    1  (-1.11397, -1.10518]
#
#    mean_values
# 0    -0.854993
# 1    -2.377955
# 2    -0.768501
# ...

# %%
df['2'].hist()
plt.show()

# %%
df['bins']=pd.qcut(df['3'],q=200,precision=5)
df['mean_values']=df[['3','bins']].groupby('bins').transform('mean')
df['3']=df['mean_values']
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.206963  0.072368 -0.854993  0.377274 -0.978351 -1.304464 -0.222651
# 1  1.070110 -3.654510 -2.377955 -1.485860  0.967588 -0.132138 -0.882861
# 2  1.896441 -3.654510 -0.768501 -0.917186  0.853488  1.022973 -0.352025
# 3  3.640134  1.105328  0.237479  0.189216  0.049322  1.401446  0.308535
# 4  1.472491 -1.886492 -1.110267  0.753815  0.529871  0.683457 -0.311696
#
#           7         8         9        10  CLASS  NSP                  bins  \
# 0  0.805802 -0.154134 -0.828378 -0.802710      6    1    (0.37382, 0.38092]
# 1  0.591740  1.345747 -0.346750 -0.007154      2    1  (-1.51015, -1.47271]
# 2  0.828647 -1.065434 -1.185671 -0.175735      2    1  (-0.92401, -0.91311]
# 3 -1.156985  0.285555 -0.507672  0.261899      7    2    (0.17647, 0.20114]
# 4 -0.042222  0.032792  0.123623  0.483177      1    1    (0.74722, 0.76675]
#
#    mean_values
# 0     0.377274
# 1    -1.485860
# 2    -0.917186
# ...

# %%
df['3'].hist()
plt.show()

# %%
df['bins']=pd.qcut(df['4'],q=250,precision=5)
df['mean_values']=df[['4','bins']].groupby('bins').transform('mean')
df['4']=df['mean_values']
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.206963  0.072368 -0.854993  0.377274 -0.982863 -1.304464 -0.222651
# 1  1.070110 -3.654510 -2.377955 -1.485860  0.964003 -0.132138 -0.882861
# 2  1.896441 -3.654510 -0.768501 -0.917186  0.855743  1.022973 -0.352025
# 3  3.640134  1.105328  0.237479  0.189216  0.054360  1.401446  0.308535
# 4  1.472491 -1.886492 -1.110267  0.753815  0.530912  0.683457 -0.311696
#
#           7         8         9        10  CLASS  NSP                  bins  \
# 0  0.805802 -0.154134 -0.828378 -0.802710      6    1  (-0.99256, -0.97835]
# 1  0.591740  1.345747 -0.346750 -0.007154      2    1    (0.95636, 0.97065]
# 2  0.828647 -1.065434 -1.185671 -0.175735      2    1    (0.84954, 0.86297]
# 3 -1.156985  0.285555 -0.507672  0.261899      7    2  (0.048694, 0.059049]
# 4 -0.042222  0.032792  0.123623  0.483177      1    1    (0.52135, 0.53898]
#
#    mean_values
# 0    -0.982863
# 1     0.964003
# 2     0.855743
# ...

# %%
df['4'].hist()
plt.show()

# %%
df['bins']=pd.qcut(df['5'],q=300,precision=5)
df['mean_values']=df[['5','bins']].groupby('bins').transform('mean')
df['5']=df['mean_values']
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.206963  0.072368 -0.854993  0.377274 -0.982863 -1.325552 -0.222651
# 1  1.070110 -3.654510 -2.377955 -1.485860  0.964003 -0.134325 -0.882861
# 2  1.896441 -3.654510 -0.768501 -0.917186  0.855743  1.026395 -0.352025
# 3  3.640134  1.105328  0.237479  0.189216  0.054360  1.406423  0.308535
# 4  1.472491 -1.886492 -1.110267  0.753815  0.530912  0.686739 -0.311696
#
#           7         8         9        10  CLASS  NSP                  bins  \
# 0  0.805802 -0.154134 -0.828378 -0.802710      6    1    (-1.3494, -1.3039]
# 1  0.591740  1.345747 -0.346750 -0.007154      2    1  (-0.13728, -0.13172]
# 2  0.828647 -1.065434 -1.185671 -0.175735      2    1     (1.0171, 1.03576]
# 3 -1.156985  0.285555 -0.507672  0.261899      7    2    (1.39695, 1.41588]
# 4 -0.042222  0.032792  0.123623  0.483177      1    1     (0.6804, 0.69006]
#
#    mean_values
# 0    -1.325552
# 1    -0.134325
# 2     1.026395
# ...

# %%
df['5'].hist()
plt.show()

# %%
df['bins']=pd.qcut(df['6'],q=200,precision=5)
df['mean_values']=df[['6','bins']].groupby('bins').transform('mean')
df['6']=df['mean_values']
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.206963  0.072368 -0.854993  0.377274 -0.982863 -1.325552 -0.222853
# 1  1.070110 -3.654510 -2.377955 -1.485860  0.964003 -0.134325 -0.879254
# 2  1.896441 -3.654510 -0.768501 -0.917186  0.855743  1.026395 -0.349085
# 3  3.640134  1.105328  0.237479  0.189216  0.054360  1.406423  0.309231
# 4  1.472491 -1.886492 -1.110267  0.753815  0.530912  0.686739 -0.308998
#
#           7         8         9        10  CLASS  NSP                  bins  \
# 0  0.805802 -0.154134 -0.828378 -0.802710      6    1  (-0.22642, -0.21503]
# 1  0.591740  1.345747 -0.346750 -0.007154      2    1   (-0.89118, -0.8699]
# 2  0.828647 -1.065434 -1.185671 -0.175735      2    1   (-0.35349, -0.3436]
# 3 -1.156985  0.285555 -0.507672  0.261899      7    2    (0.30449, 0.31478]
# 4 -0.042222  0.032792  0.123623  0.483177      1    1  (-0.31222, -0.30488]
#
#    mean_values
# 0    -0.222853
# 1    -0.879254
# 2    -0.349085
# ...

# %%
df['6'].hist()
plt.show()

# %%
df['bins']=pd.qcut(df['7'],q=50,precision=5)
df['mean_values']=df[['7','bins']].groupby('bins').transform('mean')
df['7']=df['mean_values']
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.206963  0.072368 -0.854993  0.377274 -0.982863 -1.325552 -0.222853
# 1  1.070110 -3.654510 -2.377955 -1.485860  0.964003 -0.134325 -0.879254
# 2  1.896441 -3.654510 -0.768501 -0.917186  0.855743  1.026395 -0.349085
# 3  3.640134  1.105328  0.237479  0.189216  0.054360  1.406423  0.309231
# 4  1.472491 -1.886492 -1.110267  0.753815  0.530912  0.686739 -0.308998
#
#           7         8         9        10  CLASS  NSP                   bins  \
# 0  0.780923 -0.154134 -0.828378 -0.802710      6    1     (0.75296, 0.81197]
# 1  0.603913  1.345747 -0.346750 -0.007154      2    1       (0.568, 0.62632]
# 2  0.830658 -1.065434 -1.185671 -0.175735      2    1     (0.81197, 0.85904]
# 3 -1.116462  0.285555 -0.507672  0.261899      7    2   (-1.18182, -1.06396]
# 4 -0.049929  0.032792  0.123623  0.483177      1    1  (-0.065803, -0.03142]
#
#    mean_values
# 0     0.780923
# 1     0.603913
# 2     0.830658
# ...

# %%
df['7'].hist()
plt.show()

# %%
df['bins']=pd.qcut(df['8'],q=40,precision=5)
df['mean_values']=df[['8','bins']].groupby('bins').transform('mean')
df['8']=df['mean_values']
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.206963  0.072368 -0.854993  0.377274 -0.982863 -1.325552 -0.222853
# 1  1.070110 -3.654510 -2.377955 -1.485860  0.964003 -0.134325 -0.879254
# 2  1.896441 -3.654510 -0.768501 -0.917186  0.855743  1.026395 -0.349085
# 3  3.640134  1.105328  0.237479  0.189216  0.054360  1.406423  0.309231
# 4  1.472491 -1.886492 -1.110267  0.753815  0.530912  0.686739 -0.308998
#
#           7         8         9        10  CLASS  NSP                    bins  \
# 0  0.780923 -0.169192 -0.828378 -0.802710      6    1    (-0.18946, -0.15038]
# 1  0.603913  1.454561 -0.346750 -0.007154      2    1      (1.26957, 1.66237]
# 2  0.830658 -1.143961 -1.185671 -0.175735      2    1    (-1.25261, -1.05896]
# 3 -1.116462  0.298965 -0.507672  0.261899      7    2      (0.28009, 0.32294]
# 4 -0.049929  0.012509  0.123623  0.483177      1    1  (-0.0029479, 0.032829]
#
#    mean_values
# 0    -0.169192
# 1     1.454561
# ...

# %%
df['8'].hist()
plt.show()

# %%
df['bins']=pd.qcut(df['9'],q=40,precision=5)
df['mean_values']=df[['9','bins']].groupby('bins').transform('mean')
df['9']=df['mean_values']
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.206963  0.072368 -0.854993  0.377274 -0.982863 -1.325552 -0.222853
# 1  1.070110 -3.654510 -2.377955 -1.485860  0.964003 -0.134325 -0.879254
# 2  1.896441 -3.654510 -0.768501 -0.917186  0.855743  1.026395 -0.349085
# 3  3.640134  1.105328  0.237479  0.189216  0.054360  1.406423  0.309231
# 4  1.472491 -1.886492 -1.110267  0.753815  0.530912  0.686739 -0.308998
#
#           7         8         9        10  CLASS  NSP                  bins  \
# 0  0.780923 -0.169192 -0.785622 -0.802710      6    1  (-0.88225, -0.71031]
# 1  0.603913  1.454561 -0.342014 -0.007154      2    1  (-0.36651, -0.31947]
# 2  0.830658 -1.143961 -1.210139 -0.175735      2    1  (-1.39604, -1.08618]
# 3 -1.116462  0.298965 -0.500292  0.261899      7    2  (-0.53495, -0.46495]
# 4 -0.049929  0.012509  0.118455  0.483177      1    1    (0.10196, 0.13302]
#
#    mean_values
# 0    -0.785622
# 1    -0.342014
# 2    -1.210139
# ...

# %%
df['9'].hist()
plt.show()

# %%
df['bins']=pd.qcut(df['10'],q=40,precision=5)
df['mean_values']=df[['10','bins']].groupby('bins').transform('mean')
df['10']=df['mean_values']
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.206963  0.072368 -0.854993  0.377274 -0.982863 -1.325552 -0.222853
# 1  1.070110 -3.654510 -2.377955 -1.485860  0.964003 -0.134325 -0.879254
# 2  1.896441 -3.654510 -0.768501 -0.917186  0.855743  1.026395 -0.349085
# 3  3.640134  1.105328  0.237479  0.189216  0.054360  1.406423  0.309231
# 4  1.472491 -1.886492 -1.110267  0.753815  0.530912  0.686739 -0.308998
#
#           7         8         9        10  CLASS  NSP                   bins  \
# 0  0.780923 -0.169192 -0.785622 -0.824508      6    1   (-0.89712, -0.76595]
# 1  0.603913  1.454561 -0.342014 -0.009280      2    1  (-0.02037, 0.0011394]
# 2  0.830658 -1.143961 -1.210139 -0.180885      2    1   (-0.19335, -0.16753]
# 3 -1.116462  0.298965 -0.500292  0.271784      7    2     (0.25135, 0.29421]
# 4 -0.049929  0.012509  0.118455  0.501488      1    1     (0.46609, 0.53475]
#
#    mean_values
# 0    -0.824508
# 1    -0.009280
# 2    -0.180885
# ...

# %%
df['10'].hist()
plt.show()

# %%
df.iloc[:,:11].hist()
plt.show()

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.206963  0.072368 -0.854993  0.377274 -0.982863 -1.325552 -0.222853
# 1  1.070110 -3.654510 -2.377955 -1.485860  0.964003 -0.134325 -0.879254
# 2  1.896441 -3.654510 -0.768501 -0.917186  0.855743  1.026395 -0.349085
# 3  3.640134  1.105328  0.237479  0.189216  0.054360  1.406423  0.309231
# 4  1.472491 -1.886492 -1.110267  0.753815  0.530912  0.686739 -0.308998
#
#           7         8         9        10  CLASS  NSP                   bins  \
# 0  0.780923 -0.169192 -0.785622 -0.824508      6    1   (-0.89712, -0.76595]
# 1  0.603913  1.454561 -0.342014 -0.009280      2    1  (-0.02037, 0.0011394]
# 2  0.830658 -1.143961 -1.210139 -0.180885      2    1   (-0.19335, -0.16753]
# 3 -1.116462  0.298965 -0.500292  0.271784      7    2     (0.25135, 0.29421]
# 4 -0.049929  0.012509  0.118455  0.501488      1    1     (0.46609, 0.53475]
#
#    mean_values
# 0    -0.824508
# 1    -0.009280
# 2    -0.180885
# ...

# %%
df=df.iloc[:,:13]
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.206963  0.072368 -0.854993  0.377274 -0.982863 -1.325552 -0.222853
# 1  1.070110 -3.654510 -2.377955 -1.485860  0.964003 -0.134325 -0.879254
# 2  1.896441 -3.654510 -0.768501 -0.917186  0.855743  1.026395 -0.349085
# 3  3.640134  1.105328  0.237479  0.189216  0.054360  1.406423  0.309231
# 4  1.472491 -1.886492 -1.110267  0.753815  0.530912  0.686739 -0.308998
#
#           7         8         9        10  CLASS  NSP
# 0  0.780923 -0.169192 -0.785622 -0.824508      6    1
# 1  0.603913  1.454561 -0.342014 -0.009280      2    1
# 2  0.830658 -1.143961 -1.210139 -0.180885      2    1
# 3 -1.116462  0.298965 -0.500292  0.271784      7    2
# 4 -0.049929  0.012509  0.118455  0.501488      1    1

# %%
df.iloc[:,0:11].boxplot()
plt.show()

# %% [markdown]
# # Καθώς έχουμε κάνει pca τα πρώτα features  περιέχουν περισσότερη πρηροφορία από τα τελεταυταία συνεπώς θα επιλέξουμε μεγάλο q στα πρώτα και στα τελευταία έχουμε την άνεση να 'θυσιάσουμε' ακρίβεια και να κερδίσουμε numerocity reduction
# # Επιπλέον παρατηρούμε ότι φέραμε τα outliers πιο κοντά.

# %% [markdown]
# # df.to_csv('pre_feature_selection.csv')

# %% [markdown]
# # df = df.sample(frac = 1) #suffleing beforehand to compare results with different combinations of features
# # df.to_csv('knn_pre_feature_selection.csv')
